# %% [markdown]
# # Content Creation with CrewAI
#
# Welcome to the first practice lab of this course!
#
# In this lab , you'll see an example of using CrewAI for content creation. This demonstrates how to build a single-agent system for planning YouTube Shorts content.
#
# **What you'll see:**
# - How to define an agent with a specific content creation role
# - How to create a task with structured output requirements
# - How to assemble an agent and task into a crew
# - How CrewAI executes the workflow
#
# **What this example builds:**
# A **Content Planning Agent** that creates a weekly content calendar for YouTube Shorts focusing on micro-history topics.
#
# ## Background
#
# You're a content creator focusing on short-form video content about the surprising origins of everyday things. You want to create engaging 30-45 second YouTube Shorts that:
# - Hooks viewers in the first second
# - Tells a clear story with a surprising twist
# - Drives engagement through comments
# - Can be filmed at home with minimal equipment
#
# Instead of manually brainstorming and planning content, you'll use an AI agent to generate a structured weekly content plan.
#
# ## General instructions
# In this lab you will be presented with a structure of the code, but you will need to complete some of it.
#
# To successfully run this lab, replace all instances of the placeholder `None` with your own code. Sections where you need to write code will be delimited between `### START CODE HERE ###` and `### END CODE HERE ###`.
#
# **<font color='#5DADEC'>Please make sure to save your work periodically, so you don't lose any progress.</font>**

# %% [markdown]
# ## Table of Contents
#
# - [1. Set Up Your Notebook](#1)
# - [2. Define the Content Planning Agent](#2)
# - [3. Define the Content Planning Task](#3)
# - [4. Create and Run the Crew](#4)
# - [5. Review the Results](#5)

# %% [markdown]
# <a id="1"></a>
#
# ## 1. Set Up Your Notebook
#
# First, import the necessary modules and configure the environment.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Task, Agent, Crew
import os
os.environ["CREWAI_TESTING"] = "true"
from utils import get_openai_api_key
from utils import get_openai_base_url

os.environ["OPENAI_API_KEY"] = get_openai_api_key() 
os.environ["OPENAI_BASE_URL"] = get_openai_base_url()

# %% [markdown]
# <a id="2"></a>
#
# ## 2. Define the Content Planning Agent
#
# Content creation is an excellent use case for AI agents because it involves:
# - **Strategy**: Understanding platform requirements and audience psychology
# - **Creativity**: Generating engaging hooks and concepts
# - **Structure**: Organizing content in a repeatable, scalable format
#
# In this example, you'll create a single specialized agent:
#
# **Content Planning Agent:**
# - Plans a weekly slate of video concepts
# - Ensures each video follows best practices for retention
# - Keeps ideas practical and filmable for a solo creator
#
# The agent will produce a structured JSON output with video blueprints that include titles, hooks, visual ideas, tags, and calls-to-action.
#
# Agents in CrewAI represent team members with specific roles, goals, and expertise. Each agent has:
# - **Role**: Their job title or function
# - **Goal**: What they aim to achieve
# - **Backstory**: Their experience and expertise. This helps the LLM understand how to roleplay the agent.
# - **LLM**: The language model to use (in this case, gpt-4o-mini)
# - **Verbose**: Whether to show detailed output (useful for learning and debugging)
#
# Use the next cell to create your very own agent! Try following best practices, as shown by João.

# %%
# Define the Content Planning Agent
content_creator_assistant = Agent(
    ### START CODE HERE
    role="Content Planning Specialist",
    goal="Create a weekly content calendar for engaging YouTube Shorts about micro-history topics",
    backstory=(
        "You are an experienced content strategist specializing in short-form video content. "
        "You understand viral video psychology, retention tactics, and how to craft compelling "
        "narratives for 30-45 second videos. You excel at finding surprising historical facts "
        "and turning them into engaging, filmable content for solo creators."
    ),
    llm="gpt-4o-mini",
    verbose=True,
    ### END CODE HERE ###
)

print("✓ Content planning agent defined")
# Out:
# ✓ Content planning agent defined

# %% [markdown]
# <a id="3"></a>
#
# ## 3. Define the Content Planning Task
#
# Tasks define the actual work that agents will perform. Each task has:
# - **Description**: What needs to be done, including context and requirements
# - **Expected Output**: What the result should look like (in this case, a JSON schema)
# - **Agent**: Which agent will perform this task
#
# Let's create a task that generates a weekly content plan with structured video blueprints. Once again, try using best practices to fill in the fields.

# %%
# Define the Content Planning Task
task = Task(
    ### START CODE HERE ###
    description=(
        "Create a weekly content plan for 5 YouTube Shorts videos about micro-history topics. "
        "Each video should focus on the surprising origins of everyday things. "
        "For each video, provide: "
        "1. A compelling title that hints at the surprise "
        "2. A hook (first 3 seconds) that immediately grabs attention "
        "3. The main story beats for a 30-45 second narrative "
        "4. Visual suggestions that can be filmed at home "
        "5. Relevant hashtags for discoverability "
        "6. A call-to-action that drives engagement "
        "Ensure the content is factually accurate, engaging, and practical to produce."
    ),
    expected_output=(
        "A JSON formatted weekly content plan containing 5 video blueprints. "
        "Each blueprint should include: title, hook, story_beats (array), "
        "visual_suggestions (array), hashtags (array), and call_to_action. "
        "The output should be structured, detailed, and ready to use for content production."
    ),
    agent=content_creator_assistant
    ### END CODE HERE ###
)

print("✓ Content planning task defined")
# Out:
# ✓ Content planning task defined

# %% [markdown]
# <a id="4"></a>
#
# ## 4. Create and Run the Crew
#
# Now you'll assemble the agent and task into a **Crew**. Even with a single agent, CrewAI provides a structured way to organize and execute the workflow.
#
# The crew will:
# 1. Execute the task using the agent
# 2. Use the LLM to power agent reasoning and content generation
# 3. Return structured output according to the expected format

# %%
# Create the content planning crew
crew = Crew(
    ### START CODE HERE ###
    agents=[content_creator_assistant],
    tasks=[task]
    ### END CODE HERE ###
)

print("✓ Content planning crew created")
print("\n🚀 Starting content planning...\n")

# Execute the crew's task
result = crew.kickoff()

print("\n✓ Content planning complete!")
# Out:
# ✓ Content planning crew created
#
# 🚀 Starting content planning...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planning Specialist                                                                             │
# │                                                                                                                 │
# │  Task: Create a weekly content plan for 5 YouTube Shorts videos about micro-history topics. Each video should   │
# │  focus on the surprising origins of everyday things. For each video, provide: 1. A compelling title that hints  │
# │  at the surprise 2. A hook (first 3 seconds) that immediately grabs attention 3. The main story beats for a     │
# │  30-45 second narrative 4. Visual suggestions that can be filmed at home 5. Relevant hashtags for               │
# │  discoverability 6. A call-to-action that drives engagement Ensure the content is factually accurate,           │
# │  engaging, and practical to produce.                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planning Specialist                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ```json                                                                                                        │
# │  {                                                                                                              │
# │    "weekly_content_plan": [                                                                                     │
# │      {                                                                                                          │
# │        "title": "How Coffee Became the World's Favorite Drink",                                                 │
# │        "hook": "Did you know coffee was once banned in the 17th century?",                                      │
# │        "story_beats": [                                                                                         │
# │          "Introduce the bizarre fact about coffee bans in different cultures.",                                 │
# │          "Explain how coffeehouses became centers of discussion and rebellion.",                                │
# │          "Share how the ban in Mecca led to an underground coffee movement.",                                   │
# │          "Describe how it spread to Europe, becoming a staple drink."                                           │
# │        ],                                                                                                       │
# │        "visual_suggestions": [                                                                                  │
# │          "Show a close-up of a coffee cup and beans.",                                                          │
# │          "Recreate a 17th-century coffeehouse scene using home props.",                                         │
# │          "Use graphics to illustrate its journey on a world map."                                               │
# │        ],                                                                                                       │
# │        "hashtags": ["#CoffeeHistory", "#DidYouKnow", "#MicroHistory"],                                          │
# │        "call_to_action": "Comment below your favorite coffee drink!"                                            │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "title": "The Surprising Origin of Toothbrushes",                                                        │
# │        "hook": "Did you know the first toothbrush was made from animal bones?",                                 │
# │        "story_beats": [                                                                                         │
# │          "Describe the history of oral hygiene before modern toothbrushes.",                                    │
# │          "Explain how the first toothbrush in the 15th century used animal hair.",                              │
# │          "Highlight the evolution of toothbrushes through the 20th century.",                                   │
# │          "Connect it to today’s eco-friendly alternatives."                                                     │
# │        ],                                                                                                       │
# │        "visual_suggestions": [                                                                                  │
# │          "Show different types of toothbrushes from past to present.",                                          │
# │          "Create a visual timeline with homemade drawings.",                                                    │
# │          "Demonstrate how to make a simple, sustainable toothbrush."                                            │
# │        ],                                                                                                       │
# │        "hashtags": ["#ToothbrushHistory", "#OralHygiene", "#DentalCare"],                                       │
# │        "call_to_action": "Like if you're using an eco-friendly toothbrush!"                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "title": "Why Do We Say 'Bless You' When You Sneeze?",                                                   │
# │        "hook": "Sneezing could once mean you were possessed—here's why!",                                       │
# │        "story_beats": [                                                                                         │
# │          "Explain the historical belief around sneezing and evil spirits.",                                     │
# │          "Narrate how the phrase 'God bless you' was a protective measure.",                                    │
# │          "Discuss the ritual's evolution into modern etiquette.",                                               │
# │          "Mention similar customs in different cultures."                                                       │
# │        ],                                                                                                       │
# │        "visual_suggestions": [                                                                                  │
# │          "Reenact a sneeze with family or pets.",                                                               │
# │          "Use props like a shield or a spell book for comedic effect.",                                         │
# │          "Display a cultural map showing sneezing customs worldwide."                                           │
# │        ],                                                                                                       │
# │        "hashtags": ["#BlessYou", "#SneezingEtiquette", "#MicroHistory"],                                        │
# │        "call_to_action": "Share your funniest sneeze story below!"                                              │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "title": "The Unexpected Roots of the Sandwich",                                                         │
# │        "hook": "Did you know the sandwich was invented by an Earl who loved to gamble?",                        │
# │        "story_beats": [                                                                                         │
# │          "Introduce John Montagu, the 4th Earl of Sandwich's gambling habit.",                                  │
# │          "Explain how he asked for meat between two slices of bread.",                                          │
# │          "Discuss its rise in popularity during the 18th century.",                                             │
# │          "Highlight how it evolved into countless varieties today."                                             │
# │        ],                                                                                                       │
# │        "visual_suggestions": [                                                                                  │
# │          "Create your own unique sandwich and show the ingredients.",                                           │
# │          "Reenact a brief gambling scene at a table.",                                                          │
# │          "Rapid-fire show different sandwiches from around the world."                                          │
# │        ],                                                                                                       │
# │        "hashtags": ["#SandwichHistory", "#FoodFacts", "#MicroHistory"],                                         │
# │        "call_to_action": "What's your favorite sandwich filling? Let us know!"                                  │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "title": "The Strange History Behind Perfume",                                                           │
# │        "hook": "What if I told you perfume dates back to ancient Egypt?",                                       │
# │        "story_beats": [                                                                                         │
# │          "Share the origins of perfume in ancient cultures, focusing on Egypt.",                                │
# │          "Explain how it was used in rituals and by royalty.",                                                  │
# │          "Narrate the trade routes that spread fragrance knowledge.",                                           │
# │          "Connect the past to today’s complex perfume art."                                                     │
# │        ],                                                                                                       │
# │        "visual_suggestions": [                                                                                  │
# │          "Show different bottles of perfume or essential oils.",                                                │
# │          "Create a small 'perfume lab' to mix scents at home.",                                                 │
# │          "Illustrate ancient Egypt decor with props or drawings."                                               │
# │        ],                                                                                                       │
# │        "hashtags": ["#PerfumeHistory", "#Fragrance", "#MicroHistory"],                                          │
# │        "call_to_action": "What's your go-to fragrance? Tell us in the comments!"                                │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✓ Content planning complete!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# <a id="5"></a>
#
# ## 5. Review the Results
#
# Let's examine the output from the content planning task. The agent should have generated a structured JSON with 5 video blueprints for the week.

# %%
# Display the content plan
print("=" * 80)
print("WEEKLY CONTENT PLAN")
print("=" * 80)
print(result.raw)
# Out:
# ================================================================================
# WEEKLY CONTENT PLAN
# ================================================================================
# ```json
# {
#   "weekly_content_plan": [
#     {
#       "title": "How Coffee Became the World's Favorite Drink",
#       "hook": "Did you know coffee was once banned in the 17th century?",
#       "story_beats": [
#         "Introduce the bizarre fact about coffee bans in different cultures.",
#         "Explain how coffeehouses became centers of discussion and rebellion.",
#         "Share how the ban in Mecca led to an underground coffee movement.",
#         "Describe how it spread to Europe, becoming a staple drink."
#       ],
#       "visual_suggestions": [
#         "Show a close-up of a coffee cup and beans.",
#         "Recreate a 17th-century coffeehouse scene using home props.",
#         "Use graphics to illustrate its journey on a world map."
#       ],
#       "hashtags": ["#CoffeeHistory", "#DidYouKnow", "#MicroHistory"],
#       "call_to_action": "Comment below your favorite coffee drink!"
#     },
#     {
#       "title": "The Surprising Origin of Toothbrushes",
#       "hook": "Did you know the first toothbrush was made from animal bones?",
#       "story_beats": [
#         "Describe the history of oral hygiene before modern toothbrushes.",
#         "Explain how the first toothbrush in the 15th century used animal hair.",
#         "Highlight the evolution of toothbrushes through the 20th century.",
#         "Connect it to today’s eco-friendly alternatives."
#       ],
#       "visual_suggestions": [
#         "Show different types of toothbrushes from past to present.",
#         "Create a visual timeline with homemade drawings.",
#         "Demonstrate how to make a simple, sustainable toothbrush."
#       ],
#       "hashtags": ["#ToothbrushHistory", "#OralHygiene", "#DentalCare"],
#       "call_to_action": "Like if you're using an eco-friendly toothbrush!"
#     },
#     {
#       "title": "Why Do We Say 'Bless You' When You Sneeze?",
#       "hook": "Sneezing could once mean you were possessed—here's why!",
#       "story_beats": [
#         "Explain the historical belief around sneezing and evil spirits.",
#         "Narrate how the phrase 'God bless you' was a protective measure.",
#         "Discuss the ritual's evolution into modern etiquette.",
#         "Mention similar customs in different cultures."
#       ],
#       "visual_suggestions": [
#         "Reenact a sneeze with family or pets.",
#         "Use props like a shield or a spell book for comedic effect.",
#         "Display a cultural map showing sneezing customs worldwide."
#       ],
#       "hashtags": ["#BlessYou", "#SneezingEtiquette", "#MicroHistory"],
#       "call_to_action": "Share your funniest sneeze story below!"
#     },
#     {
#       "title": "The Unexpected Roots of the Sandwich",
#       "hook": "Did you know the sandwich was invented by an Earl who loved to gamble?",
#       "story_beats": [
#         "Introduce John Montagu, the 4th Earl of Sandwich's gambling habit.",
#         "Explain how he asked for meat between two slices of bread.",
#         "Discuss its rise in popularity during the 18th century.",
#         "Highlight how it evolved into countless varieties today."
#       ],
#       "visual_suggestions": [
#         "Create your own unique sandwich and show the ingredients.",
#         "Reenact a brief gambling scene at a table.",
#         "Rapid-fire show different sandwiches from around the world."
#       ],
#       "hashtags": ["#SandwichHistory", "#FoodFacts", "#MicroHistory"],
#       "call_to_action": "What's your favorite sandwich filling? Let us know!"
#     },
#     {
#       "title": "The Strange History Behind Perfume",
#       "hook": "What if I told you perfume dates back to ancient Egypt?",
#       "story_beats": [
#         "Share the origins of perfume in ancient cultures, focusing on Egypt.",
#         "Explain how it was used in rituals and by royalty.",
#         "Narrate the trade routes that spread fragrance knowledge.",
#         "Connect the past to today’s complex perfume art."
#       ],
#       "visual_suggestions": [
#         "Show different bottles of perfume or essential oils.",
#         "Create a small 'perfume lab' to mix scents at home.",
#         "Illustrate ancient Egypt decor with props or drawings."
#       ],
#       "hashtags": ["#PerfumeHistory", "#Fragrance", "#MicroHistory"],
#       "call_to_action": "What's your go-to fragrance? Tell us in the comments!"
#     }
#   ]
# }
# ```

# %% [markdown]
# Congratulations! You've successfully finished this lab. See you in the next one. 🚀
